# %%
import requests
import pandas as pd

# %%
import requests

url = 'http://openapi.seoul.go.kr:8088/6a61584b6973756e383870526a5644/json/SebcCollegeInfoKor/1/100/'

# %%
response = requests.get(url)

# %%
print(response.content)
# Out:
# b'{"SebcCollegeInfoKor":{"list_total_count":64,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"MAIN_KEY":"BE_LiST23-0034","YEAR":"2013","CATE1_NAME":"\xec\x9d\xbc\xeb\xb0\x98\xeb\x8c\x80\xed\x95\x99","NAME_KOR":"\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xed\x95\x99\xea\xb5\x90","BRANCH":"\xeb\xb3\xb8\xea\xb5\x90","STATE":"\xea\xb8\xb0\xec\xa1\xb4","TYPE":"\xea\xb3\xb5\xeb\xa6\xbd","POSTCODE":"","ADD_KOR":"\xec\x84\x9c\xec\x9a\xb8 \xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac \xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c\xeb\xa6\xbd\xeb\x8c\x80\xeb\xa1\x9c 163 (\xec\xa0\x84\xeb\x86\x8d\xeb\x8f\x99 90\xeb\xb2\x88\xec\xa7\x80) ","ADD_KOR_ROAD":"","H_KOR_CITY":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c","H_KOR_GU":"\xeb\x8f\x99\xeb\x8c\x80\xeb\xac\xb8\xea\xb5\xac","H_KOR_DONG":"\xed\x9c\x98\xea\xb2\xbd2\xeb\x8f\x99","TEL":"02-6490-6114","FAX":"02
# ...

# %%
data = response.json()
data
# Out:
# {'SebcCollegeInfoKor': {'list_total_count': 64,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'MAIN_KEY': 'BE_LiST23-0034',
#     'YEAR': '2013',
#     'CATE1_NAME': '일반대학',
#     'NAME_KOR': '서울시립대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '공립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 동대문구 서울시립대로 163 (전농동 90번지) ',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '동대문구',
#     'H_KOR_DONG': '휘경2동',
#     'TEL': '02-6490-6114',
#     'FAX': '02-2210-5576',
#     'HP': 'http://www.uos.ac.kr'},
#    {'MAIN_KEY': 'BE_LiST23-0035',
#     'YEAR': '2013',
#     'CATE1_NAME': '전문대학(3년제)',
#     'NAME_KOR': '서울여자간호대학교',
#     'BRANCH': '본교',
#     'STATE': '기존',
#     'TYPE': '사립',
#     'POSTCODE': '',
#     'ADD_KOR': '서울 서대문구 홍제3동 서울여자간호대학',
#     'ADD_KOR_ROAD': '',
#     'H_KOR_CITY': '서울특별시',
#     'H_KOR_GU': '서대문구',
#     'H_KOR_DONG': '홍제2동',
#     'TEL': '02-2287-1700',
#     'FAX': '02-395-8018',
# ...

# %%
temp=[]
for d in data['SebcCollegeInfoKor']['row']:
  temp.append(d)
uni = pd.DataFrame(temp)
uni
# Out:
#           MAIN_KEY  YEAR CATE1_NAME   NAME_KOR BRANCH   STATE   TYPE POSTCODE  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교     본교      기존     공립
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교     본교      기존     사립
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교     본교      기존     사립
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교     본교  학교명 변경     사립
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교     본교      기존     사립
# ..             ...   ...        ...        ...    ...     ...    ...      ...
# 59  BE_LiST23-0029  2013       교육대학    서울교육대학교     본교      기존     국립
# 60  BE_LiST23-0030  2013       일반대학    서울기독대학교     본교      기존     사립
# 61  BE_LiST23-0031  2013       일반대학      서울대학교     본교      기존  국립대법인
# 62  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교     본교      기존     사립
# 63  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교     본교      기존     사립
#
#                                   ADD_KOR ADD_KOR_ROAD H_KOR_CITY H_KOR_GU  \
# ...

# %%
uniData = pd.DataFrame(temp)
uniData
# Out:
#           MAIN_KEY  YEAR CATE1_NAME   NAME_KOR BRANCH   STATE   TYPE POSTCODE  \
# 0   BE_LiST23-0034  2013       일반대학    서울시립대학교     본교      기존     공립
# 1   BE_LiST23-0035  2013  전문대학(3년제)  서울여자간호대학교     본교      기존     사립
# 2   BE_LiST23-0036  2013       일반대학    서울여자대학교     본교      기존     사립
# 3   BE_LiST23-0037  2013  전문대학(2년제)      서일대학교     본교  학교명 변경     사립
# 4   BE_LiST23-0038  2013       일반대학     성공회대학교     본교      기존     사립
# ..             ...   ...        ...        ...    ...     ...    ...      ...
# 59  BE_LiST23-0029  2013       교육대학    서울교육대학교     본교      기존     국립
# 60  BE_LiST23-0030  2013       일반대학    서울기독대학교     본교      기존     사립
# 61  BE_LiST23-0031  2013       일반대학      서울대학교     본교      기존  국립대법인
# 62  BE_LiST23-0032  2013  사이버대학(대학)   서울디지털대학교     본교      기존     사립
# 63  BE_LiST23-0033  2013  사이버대학(대학)   서울사이버대학교     본교      기존     사립
#
#                                   ADD_KOR ADD_KOR_ROAD H_KOR_CITY H_KOR_GU  \
# ...

# %%
url = 'http://openapi.seoul.go.kr:8088/6a61584b6973756e383870526a5644/json/tbEntranceItem/1/100/'

# %%
response = requests.get(url)

# %%
print(response.content)
# Out:
# b'{"tbEntranceItem":{"list_total_count":3606,"RESULT":{"CODE":"INFO-000","MESSAGE":"\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4"},"row":[{"ID":"3007","NEW_ADDR_ID":"","FCLT_ID":"P0877","FCLT_NM":"\xea\xbf\x88\xeb\x8f\x99\xec\x82\xb0\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xea\xb3\xb5\xec\x9b\x90","LAT":37.650288,"LOT":127.03686,"BLDN_CLNY_YN":"BG_AA","FCLT_USG_SE":"FU_BI","RDN_ADDR":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xeb\x8f\x84\xeb\xb4\x89\xea\xb5\xac \xeb\x8f\x84\xeb\xb4\x89\xeb\xa1\x9c110\xeb\x82\x98\xea\xb8\xb8 99","LOTNO_ADDR":"\xec\x84\x9c\xec\x9a\xb8\xed\x8a\xb9\xeb\xb3\x84\xec\x8b\x9c \xeb\x8f\x84\xeb\xb4\x89\xea\xb5\xac \xec\xb0\xbd\xeb\x8f\x99 663-1","ETC":"","NTN_BRNCH_NO":"\xeb\x8b\xa4\xec\x82\xac 5914 6130","DATA_CRTR_DD":"2022-12-07 00:00:00.0"},{"ID":"3008","NEW_ADDR_ID":"","FCLT_ID":"P0878","FCLT_NM":"\xeb\xaf\xb8\xed\x99\x94\xec\x96\xb4\xeb\xa6\xb0\xec\x9d\xb4\xea\xb3\xb5\xec\x9
# ...

# %%
data2 = response.json()
data2
# Out:
# {'tbEntranceItem': {'list_total_count': 3606,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'ID': '3007',
#     'NEW_ADDR_ID': '',
#     'FCLT_ID': 'P0877',
#     'FCLT_NM': '꿈동산어린이공원',
#     'LAT': 37.650288,
#     'LOT': 127.03686,
#     'BLDN_CLNY_YN': 'BG_AA',
#     'FCLT_USG_SE': 'FU_BI',
#     'RDN_ADDR': '서울특별시 도봉구 도봉로110나길 99',
#     'LOTNO_ADDR': '서울특별시 도봉구 창동 663-1',
#     'ETC': '',
#     'NTN_BRNCH_NO': '다사 5914 6130',
#     'DATA_CRTR_DD': '2022-12-07 00:00:00.0'},
#    {'ID': '3008',
#     'NEW_ADDR_ID': '',
#     'FCLT_ID': 'P0878',
#     'FCLT_NM': '미화어린이공원',
#     'LAT': 37.654945,
#     'LOT': 127.03969,
#     'BLDN_CLNY_YN': 'BG_AA',
#     'FCLT_USG_SE': 'FU_BI',
#     'RDN_ADDR': '서울특별시 도봉구 도봉로 564',
#     'LOTNO_ADDR': '서울특별시 도봉구 창동 715-17',
#     'ETC': '',
#     'NTN_BRNCH_NO': '다사 5939 6181',
#     'DATA_CRTR_DD': '2022-12-07 00:00:00.0'},
#    {'ID': '3009',
#     'NEW_ADDR_ID': '',
#     'FCLT_ID': 'P0879',
# ...

# %%
temp=[]
for d in data2['tbEntranceItem']['row']:
  temp.append(d)
uni = pd.DataFrame(temp)
uni
# Out:
#       ID NEW_ADDR_ID FCLT_ID    FCLT_NM        LAT         LOT BLDN_CLNY_YN  \
# 0   3007               P0877   꿈동산어린이공원  37.650288  127.036860        BG_AA
# 1   3008               P0878    미화어린이공원  37.654945  127.039690        BG_AA
# 2   3009               P0879   꿈동산어린이공원  37.573290  127.045840        BG_AA
# 3   3010               P0880    새움어린이공원  37.570760  127.048676        BG_AA
# 4   3012               P0882    동산어린이공원  37.566967  127.057540        BG_AA
# ..   ...         ...     ...        ...        ...         ...          ...
# 95    46               B0046      성북프라자  37.621567  127.026460        BG_AB
# 96    47               B0047       수유시장  37.630783  127.022950        BG_AB
# 97    48               B0048   롯데마트 삼양점  37.625576  127.017715        BG_AA
# 98    49               B0049      동북프라자  37.620247  127.018790        BG_AB
# 99    50               B0050  NC백화점 강서점  37.559963  126.840350        BG_AA
#
# ...

# %%
import folium

anMap = folium.Map(location= [38.14199686,128.0710755],
                   zoom_start=11,
                   zoom_control=False,
                   comtrol_scale = True)
anMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
from folium.plugins import MarkerCluster
mc = MarkerCluster().add_to(anMap)

for n, row in uni.iterrows():
  folium.Marker(location=[row['LAT'],row['LOT']],
                popup = folium.Popup(row['FCLT_NM'], max_width=300)).add_to(mc)
anMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
